# %%
import pandas as pd

# %%
dataset_1 = pd.read_csv(r"C:\Users\MIQDAD\data\googleplaystore.csv")

# %%
print(dataset_1)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # cleaning the installs column and converting to int

# %%
dataset_1['Installs'] = dataset_1['Installs'].str.replace('+', '')
dataset_1['Installs'] = dataset_1['Installs'].str.replace(',', '')
dataset_1['Installs'] = dataset_1['Installs'].apply(lambda x: 0 if x == 'Free' else x)
dataset_1['Installs'] = dataset_1['Installs'].astype(int)
# Out:
# C:\Users\MIQDAD\AppData\Local\Temp\ipykernel_34216\258445895.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataset_1['Installs'] = dataset_1['Installs'].str.replace('+', '')

# %% [markdown]
# # the top 10 installed apps

# %%
top_10_apps = dataset_1.nlargest(10, 'Installs')

# %%
top_10_apps.plot(kind='bar', x='App', y='Installs')
# Out:
# <AxesSubplot:xlabel='App'>

# %%
print(top_10_apps)
# Out:
#                                           App             Category  Rating  \
# 152                         Google Play Books  BOOKS_AND_REFERENCE     3.9
# 335  Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 336                        WhatsApp Messenger        COMMUNICATION     4.4
# 338              Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                     Gmail        COMMUNICATION     4.3
# 341                                  Hangouts        COMMUNICATION     4.0
# 381                        WhatsApp Messenger        COMMUNICATION     4.4
# 382  Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 386                                  Hangouts        COMMUNICATION     4.0
# 391             Skype - free IM & video calls        COMMUNICATION     4.1
#
#       Reviews                Size    Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# # avg of apps and the most installed categories

# %%
mean_installs_by_category = dataset_1.groupby('Category')['Installs'].mean()

# %%
mean_installs_by_category_sorted = mean_installs_by_category.sort_values(ascending=False)

# %%
mean_installs_by_category_sorted.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
print(mean_installs_by_category_sorted)
# Out:
# Category
# COMMUNICATION          8.435989e+07
# SOCIAL                 4.769447e+07
# VIDEO_PLAYERS          3.555430e+07
# PRODUCTIVITY           3.343418e+07
# GAME                   3.066960e+07
# PHOTOGRAPHY            3.011417e+07
# TRAVEL_AND_LOCAL       2.662359e+07
# NEWS_AND_MAGAZINES     2.648876e+07
# ENTERTAINMENT          1.925611e+07
# TOOLS                  1.358573e+07
# SHOPPING               1.249173e+07
# BOOKS_AND_REFERENCE    8.318050e+06
# PERSONALIZATION        5.932385e+06
# EDUCATION              5.586231e+06
# MAPS_AND_NAVIGATION    5.286729e+06
# FAMILY                 5.201959e+06
# WEATHER                5.196348e+06
# HEALTH_AND_FITNESS     4.642441e+06
# SPORTS                 4.560350e+06
# FINANCE                2.395215e+06
# BUSINESS               2.178076e+06
# FOOD_AND_DRINK         2.156683e+06
# HOUSE_AND_HOME         1.917187e+06
# ART_AND_DESIGN         1.912894e+06
# LIFESTYLE              1.407444e+06
# DATING                 1.129533e+06
# ...
